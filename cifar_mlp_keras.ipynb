# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense,Flatten
from keras.datasets import cifar10
from keras.utils import to_categorical
from keras.optimizers import Adam
import matplotlib.pyplot as plt

# %%
(x_train,y_train),(x_test,y_test)=cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 292s 2us/step

# %%
y_train_cat=to_categorical(y_train)
y_test_cat=to_categorical(y_test)

# %%
model=Sequential()
model.add(Flatten(input_shape=(32,32,3)))
model.add(Dense(1024,activation='relu'))
model.add(Dense(512,activation='relu'))
model.add(Dense(256,activation='relu'))
model.add(Dense(128,activation='relu'))
model.add(Dense(10,activation='softmax'))
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer=Adam(learning_rate=0.0001),loss='categorical_crossentropy',metrics=['accuracy'])

# %%
result=model.fit(x_train,y_train_cat,epochs=50,batch_size=64,validation_split=0.2)
# Out:
# Epoch 1/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 31ms/step - accuracy: 0.2451 - loss: 6.4964 - val_accuracy: 0.2868 - val_loss: 2.9916
# Epoch 2/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 31ms/step - accuracy: 0.3086 - loss: 2.6186 - val_accuracy: 0.3194 - val_loss: 2.2387
# Epoch 3/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.3495 - loss: 2.0979 - val_accuracy: 0.3510 - val_loss: 2.0460
# Epoch 4/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 16s 26ms/step - accuracy: 0.3809 - loss: 1.8762 - val_accuracy: 0.3739 - val_loss: 1.8974
# Epoch 5/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 16s 26ms/step - accuracy: 0.4025 - loss: 1.7673 - val_accuracy: 0.3976 - val_loss: 1.7930
# Epoch 6/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 16s 26ms/step - accuracy: 0.4144 - loss: 1.6967 - val_accuracy: 0.3927 - val_loss: 1.7597
# Epoch 7/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 17s 26ms/step - accuracy: 0.4340 - loss: 1.6287 - val_accuracy: 0.3935 - val_loss: 1.7907
# Epoch 8/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 16s 26ms/step - accuracy: 0.4438 - loss: 1.5964 - val_accuracy: 0.4163 - val_loss: 1.6900
# Epoch 9/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.4491 - loss: 1.5634 - val_accuracy: 0.4189 - val_loss: 1.6954
# Epoch 10/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.4585 - loss: 1.5286 - val_accuracy: 0.4366 - val_loss: 1.6266
# Epoch 11/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 16s 26ms/step - accuracy: 0.4692 - loss: 1.4967 - val_accuracy: 0.4209 - val_loss: 1.6719
# Epoch 12/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 26ms/step - accuracy: 0.4825 - loss: 1.4656 - val_accuracy: 0.4334 - val_loss: 1.6613
# Epoch 13/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 16s 26ms/step - accuracy: 0.4877 - loss: 1.4435 - val_accuracy: 0.4431 - val_loss: 1.6301
# Epoch 14/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.4965 - loss: 1.4259 - val_accuracy: 0.4408 - val_loss: 1.6174
# Epoch 15/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.5035 - loss: 1.3991 - val_accuracy: 0.4528 - val_loss: 1.5855
# Epoch 16/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - accuracy: 0.5173 - loss: 1.3642 - val_accuracy: 0.4666 - val_loss: 1.5472
# Epoch 17/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 29ms/step - accuracy: 0.5209 - loss: 1.3525 - val_accuracy: 0.4507 - val_loss: 1.6515
# Epoch 18/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 28ms/step - accuracy: 0.5319 - loss: 1.3120 - val_accuracy: 0.4524 - val_loss: 1.5983
# Epoch 19/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - accuracy: 0.5429 - loss: 1.2857 - val_accuracy: 0.4625 - val_loss: 1.5703
# Epoch 20/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.5570 - loss: 1.2516 - val_accuracy: 0.4444 - val_loss: 1.6418
# Epoch 21/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - accuracy: 0.5663 - loss: 1.2264 - val_accuracy: 0.4736 - val_loss: 1.5752
# Epoch 22/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 28ms/step - accuracy: 0.5746 - loss: 1.2013 - val_accuracy: 0.4950 - val_loss: 1.5193
# Epoch 23/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 28ms/step - accuracy: 0.5844 - loss: 1.1718 - val_accuracy: 0.4925 - val_loss: 1.5032
# Epoch 24/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - accuracy: 0.5941 - loss: 1.1435 - val_accuracy: 0.4794 - val_loss: 1.6072
# Epoch 25/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 28ms/step - accuracy: 0.6050 - loss: 1.1140 - val_accuracy: 0.4931 - val_loss: 1.5370
# Epoch 26/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 27ms/step - accuracy: 0.6154 - loss: 1.0847 - val_accuracy: 0.4694 - val_loss: 1.6804
# Epoch 27/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - accuracy: 0.6233 - loss: 1.0602 - val_accuracy: 0.4897 - val_loss: 1.5793
# Epoch 28/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - accuracy: 0.6330 - loss: 1.0349 - val_accuracy: 0.4901 - val_loss: 1.5850
# Epoch 29/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 28ms/step - accuracy: 0.6401 - loss: 1.0129 - val_accuracy: 0.4673 - val_loss: 1.6865
# Epoch 30/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 28ms/step - accuracy: 0.6542 - loss: 0.9733 - val_accuracy: 0.4982 - val_loss: 1.6052
# Epoch 31/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 28ms/step - accuracy: 0.6618 - loss: 0.9514 - val_accuracy: 0.4943 - val_loss: 1.6443
# Epoch 32/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 30ms/step - accuracy: 0.6739 - loss: 0.9243 - val_accuracy: 0.4935 - val_loss: 1.6322
# Epoch 33/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 29ms/step - accuracy: 0.6797 - loss: 0.8997 - val_accuracy: 0.4884 - val_loss: 1.6862
# Epoch 34/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 29ms/step - accuracy: 0.6889 - loss: 0.8752 - val_accuracy: 0.5074 - val_loss: 1.6523
# Epoch 35/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 31ms/step - accuracy: 0.7000 - loss: 0.8485 - val_accuracy: 0.4973 - val_loss: 1.7146
# Epoch 36/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 29ms/step - accuracy: 0.7062 - loss: 0.8290 - val_accuracy: 0.5035 - val_loss: 1.7221
# Epoch 37/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 34ms/step - accuracy: 0.7143 - loss: 0.8085 - val_accuracy: 0.5008 - val_loss: 1.7303
# Epoch 38/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 36ms/step - accuracy: 0.7261 - loss: 0.7792 - val_accuracy: 0.5038 - val_loss: 1.7517
# Epoch 39/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 35ms/step - accuracy: 0.7305 - loss: 0.7552 - val_accuracy: 0.4910 - val_loss: 1.8428
# Epoch 40/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 35ms/step - accuracy: 0.7406 - loss: 0.7341 - val_accuracy: 0.5003 - val_loss: 1.8495
# Epoch 41/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 35ms/step - accuracy: 0.7478 - loss: 0.7171 - val_accuracy: 0.5031 - val_loss: 1.8245
# Epoch 42/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 35ms/step - accuracy: 0.7548 - loss: 0.6902 - val_accuracy: 0.4937 - val_loss: 1.8762
# Epoch 43/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 34ms/step - accuracy: 0.7601 - loss: 0.6814 - val_accuracy: 0.4960 - val_loss: 1.9157
# Epoch 44/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 34ms/step - accuracy: 0.7732 - loss: 0.6461 - val_accuracy: 0.4995 - val_loss: 1.9204
# Epoch 45/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 34ms/step - accuracy: 0.7775 - loss: 0.6267 - val_accuracy: 0.4890 - val_loss: 2.0738
# Epoch 46/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 34ms/step - accuracy: 0.7833 - loss: 0.6134 - val_accuracy: 0.4958 - val_loss: 2.0313
# Epoch 47/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 33ms/step - accuracy: 0.7879 - loss: 0.5994 - val_accuracy: 0.5069 - val_loss: 2.0269
# Epoch 48/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 33ms/step - accuracy: 0.7979 - loss: 0.5703 - val_accuracy: 0.4853 - val_loss: 2.1908
# Epoch 49/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 33ms/step - accuracy: 0.8029 - loss: 0.5534 - val_accuracy: 0.4890 - val_loss: 2.2432
# Epoch 50/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 33ms/step - accuracy: 0.8077 - loss: 0.5458 - val_accuracy: 0.4996 - val_loss: 2.1263

# %%
loss,test_accuracy=model.evaluate(x_test,y_test_cat)
print(test_accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5022 - loss: 2.1244
# 0.5022000074386597

# %%
predictions=model.predict(x_test)
predict_label=np.argmax(predictions,axis=1)
print(f"predicted label:{predict_label[1]}")

#Print the predicted image
for i in range(5):
    #print(f"actual:{y_test[i]}\npredicted:{predict_label[i]}")
    plt.subplot(1,5,i+1)
    plt.imshow(x_test[i])
    plt.title(f"actual:{y_test[i]}\npredicted:{predict_label[i]}")
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# predicted label:8

# %%
plt.plot(result.history['loss'],label='train loss',color='blue')
plt.plot(result.history['val_loss'],label='valdation loss',color='red')
plt.xticks(np.arange(1,50))
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Epochs vs Loss")
plt.legend()
plt.show()

plt.plot(result.history['accuracy'],label='train accuracy',color='blue')
plt.plot(result.history['val_accuracy'],label='valdation accuracy',color='red')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Epochs vs Accuracy")
plt.legend()
plt.show()

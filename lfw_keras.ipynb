# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_lfw_people
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.utils import to_categorical

# %%
# Load dataset
lfw_people = fetch_lfw_people(min_faces_per_person=70, resize=0.4)

X = lfw_people.images  
y = lfw_people.target 
target_names = lfw_people.target_names
print("Shape of dataset:", X.shape)  
print("Number of classes:", len(target_names))
# Out:
# Shape of dataset: (1288, 50, 37)
# Number of classes: 7

# %%
# Normalize
X = X.astype("float32") / 255.0

# Reshape to (n_samples, height, width, 1)
X = X.reshape(X.shape[0], X.shape[1], X.shape[2], 1)

print("Final X shape:", X.shape)  # should be (1288, 50, 37, 1)

# Encode labels
encoder = LabelEncoder()
y_encoded = encoder.fit_transform(y)
y_cat = to_categorical(y_encoded)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y_cat, test_size=0.25, random_state=42
)

print("Train shape:", X_train.shape, "Test shape:", X_test.shape)
# Out:
# Final X shape: (1288, 50, 37, 1)
# Train shape: (966, 50, 37, 1) Test shape: (322, 50, 37, 1)

# %%
model=Sequential()
model.add(Conv2D(32,(3,3),activation='relu', input_shape=(50, 37, 1)))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(32,(3,3),activation='relu'))
model.add(MaxPooling2D((2,2)))
model.add(Flatten())
model.add(Dense(1024,activation='relu'))
model.add(Dense(512,activation='relu'))
model.add(Dense(256,activation='relu'))
model.add(Dense(128,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(target_names), activation="softmax"))
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile( optimizer="adam",loss="categorical_crossentropy", metrics=["accuracy"])

# %%
history = model.fit(X_train, y_train,validation_data=(X_test, y_test),epochs=50,batch_size=32,verbose=1)
# Out:
# Epoch 1/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.3540 - loss: 1.8286 - val_accuracy: 0.4534 - val_loss: 1.6468
# Epoch 2/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.3954 - loss: 1.7430 - val_accuracy: 0.4534 - val_loss: 1.6098
# Epoch 3/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.3986 - loss: 1.7601 - val_accuracy: 0.4534 - val_loss: 1.7214
# Epoch 4/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.3954 - loss: 1.7493 - val_accuracy: 0.4534 - val_loss: 1.6533
# Epoch 5/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.3965 - loss: 1.7458 - val_accuracy: 0.4534 - val_loss: 1.6863
# Epoch 6/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.3975 - loss: 1.7468 - val_accuracy: 0.4534 - val_loss: 1.6426
# Epoch 7/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.3975 - loss: 1.7379 - val_accuracy: 0.4534 - val_loss: 1.6152
# Epoch 8/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.3975 - loss: 1.7362 - val_accuracy: 0.4534 - val_loss: 1.6400
# Epoch 9/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.3975 - loss: 1.7352 - val_accuracy: 0.4534 - val_loss: 1.6638
# Epoch 10/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.3975 - loss: 1.7280 - val_accuracy: 0.4534 - val_loss: 1.6206
# Epoch 11/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.3975 - loss: 1.7238 - val_accuracy: 0.4534 - val_loss: 1.6457
# Epoch 12/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.3975 - loss: 1.7298 - val_accuracy: 0.4534 - val_loss: 1.6320
# Epoch 13/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.3975 - loss: 1.7316 - val_accuracy: 0.4534 - val_loss: 1.6319
# Epoch 14/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.3975 - loss: 1.7254 - val_accuracy: 0.4534 - val_loss: 1.6224
# Epoch 15/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.3975 - loss: 1.7273 - val_accuracy: 0.4534 - val_loss: 1.6219
# Epoch 16/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.3975 - loss: 1.7240 - val_accuracy: 0.4534 - val_loss: 1.6164
# Epoch 17/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.3975 - loss: 1.7258 - val_accuracy: 0.4534 - val_loss: 1.6137
# Epoch 18/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.3975 - loss: 1.7410 - val_accuracy: 0.4534 - val_loss: 1.6324
# Epoch 19/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.3975 - loss: 1.7324 - val_accuracy: 0.4534 - val_loss: 1.6211
# Epoch 20/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.3975 - loss: 1.7421 - val_accuracy: 0.4534 - val_loss: 1.6189
# Epoch 21/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.3975 - loss: 1.7208 - val_accuracy: 0.4534 - val_loss: 1.6166
# Epoch 22/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.3975 - loss: 1.7215 - val_accuracy: 0.4534 - val_loss: 1.6228
# Epoch 23/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.3975 - loss: 1.7213 - val_accuracy: 0.4534 - val_loss: 1.6183
# Epoch 24/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.3975 - loss: 1.7302 - val_accuracy: 0.4534 - val_loss: 1.6203
# Epoch 25/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.3975 - loss: 1.7260 - val_accuracy: 0.4534 - val_loss: 1.6182
# Epoch 26/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.3975 - loss: 1.7189 - val_accuracy: 0.4534 - val_loss: 1.6109
# Epoch 27/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.3975 - loss: 1.7190 - val_accuracy: 0.4534 - val_loss: 1.6229
# Epoch 28/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.3975 - loss: 1.7197 - val_accuracy: 0.4534 - val_loss: 1.6177
# Epoch 29/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.3975 - loss: 1.7210 - val_accuracy: 0.4534 - val_loss: 1.6160
# Epoch 30/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.3975 - loss: 1.7187 - val_accuracy: 0.4534 - val_loss: 1.6213
# Epoch 31/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.3975 - loss: 1.7213 - val_accuracy: 0.4534 - val_loss: 1.6158
# Epoch 32/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.3975 - loss: 1.7134 - val_accuracy: 0.4534 - val_loss: 1.6203
# Epoch 33/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.3975 - loss: 1.7186 - val_accuracy: 0.4534 - val_loss: 1.6092
# Epoch 34/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.3975 - loss: 1.7191 - val_accuracy: 0.4534 - val_loss: 1.6149
# Epoch 35/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.3975 - loss: 1.7256 - val_accuracy: 0.4534 - val_loss: 1.6072
# Epoch 36/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.3975 - loss: 1.7131 - val_accuracy: 0.4534 - val_loss: 1.6107
# Epoch 37/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.3975 - loss: 1.7306 - val_accuracy: 0.4534 - val_loss: 1.6183
# Epoch 38/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.3975 - loss: 1.7138 - val_accuracy: 0.4534 - val_loss: 1.6090
# Epoch 39/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.3975 - loss: 1.7188 - val_accuracy: 0.4534 - val_loss: 1.6082
# Epoch 40/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.3975 - loss: 1.7173 - val_accuracy: 0.4534 - val_loss: 1.5957
# Epoch 41/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.3975 - loss: 1.7126 - val_accuracy: 0.4534 - val_loss: 1.5895
# Epoch 42/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.3975 - loss: 1.7238 - val_accuracy: 0.4534 - val_loss: 1.5941
# Epoch 43/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.3975 - loss: 1.6883 - val_accuracy: 0.4534 - val_loss: 1.6487
# Epoch 44/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.3975 - loss: 1.6362 - val_accuracy: 0.4534 - val_loss: 1.5419
# Epoch 45/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.3975 - loss: 1.5809 - val_accuracy: 0.4534 - val_loss: 1.5588
# Epoch 46/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.3996 - loss: 1.6050 - val_accuracy: 0.4534 - val_loss: 1.5006
# Epoch 47/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.4213 - loss: 1.5393 - val_accuracy: 0.4658 - val_loss: 1.5401
# Epoch 48/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.4389 - loss: 1.5323 - val_accuracy: 0.4814 - val_loss: 1.4951
# Epoch 49/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.4493 - loss: 1.5201 - val_accuracy: 0.4689 - val_loss: 1.4210
# Epoch 50/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.4617 - loss: 1.4954 - val_accuracy: 0.4689 - val_loss: 1.4130

# %%
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print("Test Accuracy:", round(test_acc*100, 2), "%")
# Out:
# Test Accuracy: 46.89 %

# %%
plt.plot(history.history['loss'],label='train loss',color='blue')
plt.plot(history.history['val_loss'],label='valdation loss',color='red')
plt.xticks(np.arange(1,50))
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Epochs vs Loss")
plt.legend()
plt.show()

# %%
plt.plot(history.history['accuracy'],label='train accuracy',color='blue')
plt.plot(history.history['val_accuracy'],label='valdation accuracy',color='red')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Epochs vs Accuracy")
plt.legend()
plt.show()

# %%
import random

y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Show 5 random predictions
for i in range(5):
    idx = random.randint(0, len(X_test)-1)
    
    sample = X_test[idx].reshape(50, 37)
    predicted_class = target_names[y_pred_classes[idx]]
    actual_class = target_names[y_true_classes[idx]]
    
    plt.imshow(sample, cmap="gray")
    plt.title(f"Pred: {predicted_class}\nTrue: {actual_class}")
    plt.axis("off")
    plt.show()
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
